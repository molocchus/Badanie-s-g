# %%
import pandas as pd
import numpy as np

# %%
data_raw = pd.read_csv("Badanie_zsizo.csv")
data_raw.head()
# Out:
#      Sygnatura czasowa  Wiek       Płeć Aktualne obowiązki:  \
# 0  2025-03-06 22:36:06  23.0  Mężczyzna               Praca
# 1  2025-03-07 00:00:37  24.0  Mężczyzna       Studia, Praca
# 2  2025-03-07 11:51:21  23.0  Mężczyzna              Studia
# 3  2025-03-07 12:02:29  21.0  Mężczyzna              Studia
# 4  2025-03-07 13:04:49  24.0  Mężczyzna              Studia
#
#   O której godzinie zazwyczaj chodzisz spać?  \
# 0                                   01:50:00
# 1                                   03:00:00
# 2                                   00:00:00
# 3                                   22:30:00
# 4                                   23:59:00
#
#   O której godzinie zazwyczaj wstajesz?  \
# 0                              10:00:00
# 1                              11:00:00
# 2                              07:30:00
# 3                              06:40:00
# 4                              06:00:00
#
#   Ile godzin potrzebujesz, aby się wyspać?  \
# ...

# %%
data_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57 entries, 0 to 56
# Data columns (total 42 columns):
#  #   Column                                                                                                                                                                                                                                                                                                                    Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                                                                                                                                    --------------  -----
# ...

# %%
num_data = data_raw.select_dtypes(include=['int', 'float64'])
num_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57 entries, 0 to 56
# Data columns (total 19 columns):
#  #   Column                                                                                                     Non-Null Count  Dtype
# ---  ------                                                                                                     --------------  -----
#  0   Wiek                                                                                                       55 non-null     float64
#  1   Czy masz trudności z utrzymaniem regularnego rytmu snu?                                                    57 non-null     int64
#  2   Czy często budzisz się zmęczony/-a, mimo że spałeś/-aś wystarczająco długo?                                57 non-null     int64
#  3   Czy to jak śpisz znacząco wpływa na twoje obowiązki w pracy lub szkole?                                    57 non-null     int64
# ...

# %%
obj_data = data_raw.select_dtypes(include=['object'])
obj_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57 entries, 0 to 56
# Data columns (total 23 columns):
#  #   Column                                                                                                                                                                                                                                                                                                                    Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                                                                                                                                    --------------  -----
# ...

# %%
obj_data = obj_data.drop(obj_data.columns[i], axis=1)

# %%
# num_data['wstaje'] = pd.to_timedelta(obj_data.iloc[:,i] ).dt.total_seconds()

# %%
i = 3
print(obj_data.columns[i])
obj_data.iloc[:,i]
# Out:
# Dlaczego chodzisz spać o takich godzinach?
# 0     Nie udaje mi się utrzymywać regularnego cyklu ...
# 1     To dla mnie naturalne, Muszę wstawać i chodzić...
# 2     To dla mnie naturalne, Muszę wstawać i chodzić...
# 3     Muszę wstawać i chodzić spać o tych godzinach ...
# 4     To dla mnie naturalne, Muszę wstawać i chodzić...
# 5     Nie udaje mi się utrzymywać regularnego cyklu ...
# 6     Muszę wstawać i chodzić spać o tych godzinach ...
# 7     Muszę wstawać i chodzić spać o tych godzinach ...
# 8                                 To dla mnie naturalne
# 9     Nie udaje mi się utrzymywać regularnego cyklu ...
# 10                                To dla mnie naturalne
# 11    Muszę wstawać i chodzić spać o tych godzinach ...
# 12    Muszę wstawać i chodzić spać o tych godzinach ...
# 13                                                  NaN
# 14    Muszę wstawać i chodzić spać o tych godzinach ...
# 15    Nie udaje mi się utrzymywać regularnego cyklu ...
# ...

# %%
dum_data = dum_data.drop(dum_data.columns[62], axis=1)

# %%
dum_data.iloc[:,57] = dum_data.iloc[:,57] | dum_data.iloc[:,62]

# %%
for i, name in enumerate(dum_data.columns):
    if i > 51:
        print(i, name)
# Out:
# 52 Czy zostało u Ciebie stwierdzone lub podejrzewasz u siebie zaburzenie odżywiania takie jak anoreksja, bulimia, otyłość, niedowaga? Jeżeli tak, napisz jakie to zaburzenie._Anoreksja
# 53 Czy zostało u Ciebie stwierdzone lub podejrzewasz u siebie zaburzenie odżywiania takie jak anoreksja, bulimia, otyłość, niedowaga? Jeżeli tak, napisz jakie to zaburzenie._Bulimia
# 54 Czy zostało u Ciebie stwierdzone lub podejrzewasz u siebie zaburzenie odżywiania takie jak anoreksja, bulimia, otyłość, niedowaga? Jeżeli tak, napisz jakie to zaburzenie._Kompulsywne jedzenie
# 55 Czy zostało u Ciebie stwierdzone lub podejrzewasz u siebie zaburzenie odżywiania takie jak anoreksja, bulimia, otyłość, niedowaga? Jeżeli tak, napisz jakie to zaburzenie._Niedowaga
# 56 Czy zostało u Ciebie stwierdzone lub podejrzewasz u siebie zaburzenie odżywiania takie jak anoreksja, bulimia, otyłość, niedowaga? Jeżeli tak, napisz jakie to zaburzenie._Otyłość
# ...

# %%
dum_data.iloc[:,10] = dum_data.iloc[:,10] | dum_data2.iloc[:,18]

# %%
dum_data2 = pd.get_dummies(obj_data)
for i, name in enumerate(dum_data2.columns):
    if i > 12:
        print(i, name)
# Out:
# 13 Dlaczego chodzisz spać o takich godzinach?_Muszę wstawać i chodzić spać o tych godzinach ze względu na obowiązki
# 14 Dlaczego chodzisz spać o takich godzinach?_Muszę wstawać i chodzić spać o tych godzinach ze względu na obowiązki, Nie udaje mi się utrzymywać regularnego cyklu dobowego
# 15 Dlaczego chodzisz spać o takich godzinach?_Nie udaje mi się utrzymywać regularnego cyklu dobowego
# 16 Dlaczego chodzisz spać o takich godzinach?_To dla mnie naturalne
# 17 Dlaczego chodzisz spać o takich godzinach?_To dla mnie naturalne, Muszę wstawać i chodzić spać o tych godzinach ze względu na obowiązki
# 18 Dlaczego chodzisz spać o takich godzinach?_To dla mnie naturalne, Muszę wstawać i chodzić spać o tych godzinach ze względu na obowiązki, Nie udaje mi się utrzymywać regularnego cyklu dobowego
# 19 Dlaczego chodzisz spać o takich godzinach?_To dla mnie naturalne, Nie udaje mi się utrzymywać regularnego cyklu dobowego
# ...

# %%
dum_data = pd.get_dummies(obj_data)
dum_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57 entries, 0 to 56
# Data columns (total 80 columns):
#  #   Column                                                                                                                                                                                                                              Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                                              --------------  -----
#  0   Płeć_Kobieta                                                                                                                                                                                                                        57 non-null     bool
# ...

# %%
dum_data.to_csv("dum_data.csv")
num_data.to_csv("num_data.csv")
